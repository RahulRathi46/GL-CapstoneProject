# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../dataset/filled_0/merged.csv' , index_col=[0])

# %%
df.head()
# Out:
#          Date  Store  Dept Type    Size  MarkDown1  MarkDown2  MarkDown3  \
# 0  2010-05-02      1     1    A  151315        0.0        0.0        0.0
# 1  2010-05-02      1     2    A  151315        0.0        0.0        0.0
# 2  2010-05-02      1     3    A  151315        0.0        0.0        0.0
# 3  2010-05-02      1     4    A  151315        0.0        0.0        0.0
# 4  2010-05-02      1     5    A  151315        0.0        0.0        0.0
#
#    MarkDown4  MarkDown5         CPI  Temperature  Fuel_Price  Unemployment  \
# 0        0.0        0.0  211.096358        42.31       2.572         8.106
# 1        0.0        0.0  211.096358        42.31       2.572         8.106
# 2        0.0        0.0  211.096358        42.31       2.572         8.106
# 3        0.0        0.0  211.096358        42.31       2.572         8.106
# 4        0.0        0.0  211.096358        42.31       2.572         8.106
#
#    IsHoliday  Weekly_Sales
# 0          0      24924.50
# ...

# %%
df.describe()
# Out:
#                Store           Dept           Size      MarkDown1  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317  136727.915739    2590.074819
# std        12.785297      30.492054   60980.583328    6052.385934
# min         1.000000       1.000000   34875.000000       0.000000
# 25%        11.000000      18.000000   93638.000000       0.000000
# 50%        22.000000      37.000000  140167.000000       0.000000
# 75%        33.000000      74.000000  202505.000000    2809.050000
# max        45.000000      99.000000  219622.000000   88646.760000
#
#            MarkDown2      MarkDown3      MarkDown4      MarkDown5  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean      879.974298     468.087665    1083.132268    1662.772385
# std      5084.538801    5528.873453    3894.529945    4207.629321
# min      -265.760000     -29.100000       0.000000       0.000000
# ...

# %%
df.info() # verify updates
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 421570 entries, 0 to 421569
# Data columns (total 16 columns):
# Date            421570 non-null object
# Store           421570 non-null int64
# Dept            421570 non-null int64
# Type            421570 non-null object
# Size            421570 non-null int64
# MarkDown1       421570 non-null float64
# MarkDown2       421570 non-null float64
# MarkDown3       421570 non-null float64
# MarkDown4       421570 non-null float64
# MarkDown5       421570 non-null float64
# CPI             421570 non-null float64
# Temperature     421570 non-null float64
# Fuel_Price      421570 non-null float64
# Unemployment    421570 non-null float64
# IsHoliday       421570 non-null int64
# Weekly_Sales    421570 non-null float64
# dtypes: float64(10), int64(4), object(2)
# memory usage: 54.7+ MB

# %%
def charts(data , choice = 0 , size = (15,8)): # Data Visualization Function
    
    plt.figure(figsize=size) # Plot Figure Size
    
    if choice == 0: # Histogram Plot
        sns.distplot(data , kde = False)
        plt.show()
        
    elif choice == 1: # Bar Plot
        data = data.value_counts()
        sns.barplot(x = data.index , y = data.values , order = data.index)
        plt.show()
        
    elif choice == 2: # Distribution Plot
        sns.distplot(data , hist = False)
        plt.show()
        
    elif choice == 3: # Box Plot
        sns.boxplot(data)
        plt.show()

# %%
charts(df['Store'] , 1 , (18,7))

# %%
pd.DataFrame(df['Store'].describe()).T
# Out:
#           count       mean        std  min   25%   50%   75%   max
# Store  421570.0  22.200546  12.785297  1.0  11.0  22.0  33.0  45.0

# %% [markdown]
# 1. There are 45 unique stores with store no 13 is in top counts.
#
# 2. Bar plot does not showing any siginficatinte inference and store is catogrical type with no NaNs there is no need of any transformation but it might requied encoding preprocessing.

# %%
charts(df['Dept'] , 1 , (18,7))

# %%
pd.DataFrame(df['Dept'].describe()).T
# Out:
#          count       mean        std  min   25%   50%   75%   max
# Dept  421570.0  44.260317  30.492054  1.0  18.0  37.0  74.0  99.0

# %% [markdown]
# 1. There are 81 unique stores with dept no 79 is in top counts.
#
# 2. Bar plot does not showing any siginficatinte inference and dept is catogrical type with no NaNs there is no need of any transformation but it might requied encoding preprocessing.

# %%
charts(df['Type'] , 1 , (18,7))

# %%
pd.DataFrame(df['Type'].describe()).T
# Out:
#        count unique top    freq
# Type  421570      3   A  215478

# %%
prop = df['Type'].value_counts()
prop = (prop / prop.sum()) * 100
prop
# Out:
# A    51.113220
# B    38.782409
# C    10.104372
# Name: Type, dtype: float64

# %% [markdown]
# 1. There are 3 unique Type with Type A is in top counts.
#
# 2. There are A,B,C values are categories in Type with  51% , 38% & 10% respectivly.
#
# 3. Type is catogrical type with no NaNs there is no need of any transformation but it might requied encoding preprocessing.

# %%
charts(df['Size'] , 0 , (18,7))

# %%
charts(df['Size'] , 2 , (18,7))

# %%
charts(df['Size'] , 3 , (18,7))

# %%
pd.concat([
    pd.DataFrame(df['Size'].describe()) ,
    pd.DataFrame([df['Size'].skew()] , index=['Skew'] , columns = ['Size'])
] , axis = 0).T
# Out:
#          count           mean           std      min      25%       50%  \
# Size  421570.0  136727.915739  60980.583328  34875.0  93638.0  140167.0
#
#            75%       max     Skew
# Size  202505.0  219622.0 -0.32585

# %% [markdown]
# 1. Size variable has multiple peaks in its distribution which is due to the fact that is data has multiple catorigry and each catorigry has different means.
#
# 2. The mean (136727.91) and median (140167.0) are prety close but the data is -ve skewed (-0.32).

# %%
charts(df['MarkDown1'] , 2 , (18,7))

# %%
charts(df['MarkDown1'] , 3 , (18,7))

# %%
pd.concat([
    pd.DataFrame(df['MarkDown1'].describe()) ,
    pd.DataFrame([df['MarkDown1'].skew()] , index=['Skew'] , columns = ['MarkDown1'])
] , axis = 0).T
# Out:
#               count         mean          std  min  25%  50%      75%  \
# MarkDown1  421570.0  2590.074819  6052.385934  0.0  0.0  0.0  2809.05
#
#                 max      Skew
# MarkDown1  88646.76  4.731304

# %% [markdown]
# 1. MarkDown1 variable has multiple peaks in its distribution which is due to the fact that is data has multiple catorigry and each catorigry has different means.
#
# 2. The mean (2590.07) and strange median (0) has significant difference and the data is highly +vely skewed (4.73).
#
# 3. There many outliers present above the higer wisker which requide appropriate treatment.

# %%
charts(df['MarkDown2'] , 2 , (18,7))

# %%
charts(df['MarkDown2'] , 3 , (18,7))

# %%
pd.concat([
    pd.DataFrame(df['MarkDown2'].describe()) ,
    pd.DataFrame([df['MarkDown2'].skew()] , index=['Skew'] , columns = ['MarkDown2'])
] , axis = 0).T
# Out:
#               count        mean          std     min  25%  50%  75%  \
# MarkDown2  421570.0  879.974298  5084.538801 -265.76  0.0  0.0  2.2
#
#                  max       Skew
# MarkDown2  104519.54  10.645956

# %% [markdown]
# 1. MarkDown2 variable has multiple peaks in its distribution which is due to the fact that is data has multiple catorigry and each catorigry has different means.
#
# 2. The mean (879.97) and strange median (0) has significant difference and the data is highly +vely skewed (10.6).
#
# 3. There many outliers present above the higer wisker which requide appropriate treatment.

# %%
charts(df['MarkDown3'] , 2 , (18,7))

# %%
charts(df['MarkDown3'] , 3 , (18,7))

# %%
pd.concat([
    pd.DataFrame(df['MarkDown3'].describe()) ,
    pd.DataFrame([df['MarkDown3'].skew()] , index=['Skew'] , columns = ['MarkDown3'])
] , axis = 0).T
# Out:
#               count        mean          std   min  25%  50%   75%        max  \
# MarkDown3  421570.0  468.087665  5528.873453 -29.1  0.0  0.0  4.54  141630.61
#
#                 Skew
# MarkDown3  14.922341

# %% [markdown]
# 1. MarkDown3 variable has multiple peaks in its distribution which is due to the fact that is data has multiple catorigry and each catorigry has different means.
#
# 2. The mean (468.08) and strange median (0) has significant difference and the data is highly +vely skewed (14.9).
#
# 3. There many outliers present above the higer wisker which requide appropriate treatment.

# %%
charts(df['MarkDown4'] , 2 , (18,7))

# %%
charts(df['MarkDown4'] , 3 , (18,7))

# %%
pd.concat([
    pd.DataFrame(df['MarkDown4'].describe()) ,
    pd.DataFrame([df['MarkDown4'].skew()] , index=['Skew'] , columns = ['MarkDown4'])
] , axis = 0).T
# Out:
#               count         mean          std  min  25%  50%     75%  \
# MarkDown4  421570.0  1083.132268  3894.529945  0.0  0.0  0.0  425.29
#
#                 max      Skew
# MarkDown4  67474.85  8.077666

# %% [markdown]
# 1. MarkDown4 variable has multiple peaks in its distribution which is due to the fact that is data has multiple catorigry and each catorigry has different means.
#
# 2. The mean (1083.13) and strange median (0) has significant difference and the data is highly +vely skewed (8.07).
#
# 3. There many outliers present above the higer wisker which requide appropriate treatment.

# %%
charts(df['MarkDown5'] , 2 , (18,7))

# %%
charts(df['MarkDown5'] , 3 , (18,7))

# %%
pd.concat([
    pd.DataFrame(df['MarkDown5'].describe()) ,
    pd.DataFrame([df['MarkDown5'].skew()] , index=['Skew'] , columns = ['MarkDown5'])
] , axis = 0).T
# Out:
#               count         mean          std  min  25%  50%      75%  \
# MarkDown5  421570.0  1662.772385  4207.629321  0.0  0.0  0.0  2168.04
#
#                  max      Skew
# MarkDown5  108519.28  9.964519

# %% [markdown]
# 1. MarkDown5 variable has multiple peaks in its distribution which is due to the fact that is data has multiple catorigry and each catorigry has different means.
#
# 2. The mean (1662.77) and strange median (0) has significant difference and the data is highly +vely skewed (9.96).
#
# 3. There many outliers present above the higer wisker which requide appropriate treatment.

# %%
charts(df['CPI'] , 0 , (18,7))

# %%
charts(df['CPI'] , 2 , (18,7))

# %%
charts(df['CPI'] , 3 , (18,7))

# %%
pd.concat([
    pd.DataFrame(df['CPI'].describe()) ,
    pd.DataFrame([df['CPI'].skew()] , index=['Skew'] , columns = ['CPI'])
] , axis = 0).T
# Out:
#         count        mean        std      min         25%        50%  \
# CPI  421570.0  171.201947  39.159276  126.064  132.022667  182.31878
#
#             75%         max      Skew
# CPI  212.416993  227.232807  0.085219

# %% [markdown]
# 1. Histogram showing 3 groups in CPI variable which might due to the Store Type.
#
# 2. Variable CPI having mean of 171.20 with slight higher median of 182.31 band the data is very less skewed (0.86).

# %%
charts(df['Temperature'] , 0 , (18,7))

# %%
charts(df['Temperature'] , 2 , (18,7))

# %%
charts(df['Temperature'] , 3 , (18,7))

# %%
pd.concat([
    pd.DataFrame(df['Temperature'].describe()) ,
    pd.DataFrame([df['Temperature'].skew()] , index=['Skew'] , columns = ['Temperature'])
] , axis = 0).T
# Out:
#                 count       mean        std   min    25%    50%    75%  \
# Temperature  421570.0  60.090059  18.447931 -2.06  46.68  62.09  74.28
#
#                 max      Skew
# Temperature  100.14 -0.321404

# %% [markdown]
# 1. Temperature variable is almost normally distributed with -0.32 skewness factor.
#
# 2. Variable Temperature has mean of 60.09 and 62.09 median which is very close.

# %%
charts(df['Fuel_Price'] , 0 , (18,7))

# %%
charts(df['Fuel_Price'] , 2 , (18,7))

# %%
charts(df['Fuel_Price'] , 3 , (18,7))

# %%
pd.concat([
    pd.DataFrame(df['Fuel_Price'].describe()) ,
    pd.DataFrame([df['Fuel_Price'].skew()] , index=['Skew'] , columns = ['Fuel_Price'])
] , axis = 0).T
# Out:
#                count      mean       std    min    25%    50%    75%    max  \
# Fuel_Price  421570.0  3.361027  0.458515  2.472  2.933  3.452  3.738  4.468
#
#                 Skew
# Fuel_Price -0.104901

# %% [markdown]
# 1. Fuel_Price variable showing multiple peacks which might due to the differenct stores and there locations and each store represent its mean value.
#
# 2. Fuel_Price variable having mean of 3.36 with 3.45 as median and data is very less skewed towords -ve side.

# %%
charts(df['Unemployment'] , 0 , (18,7))

# %%
charts(df['Unemployment'] , 2 , (18,7))

# %%
charts(df['Unemployment'] , 3 , (18,7))

# %%
pd.concat([
    pd.DataFrame(df['Unemployment'].describe()) ,
    pd.DataFrame([df['Unemployment'].skew()] , index=['Skew'] , columns = ['Unemployment'])
] , axis = 0).T
# Out:
#                  count      mean       std    min    25%    50%    75%  \
# Unemployment  421570.0  7.960289  1.863296  3.879  6.891  7.866  8.572
#
#                  max      Skew
# Unemployment  14.313  1.183743

# %% [markdown]
# 1. Unemployment variable showing multiple peaks which might be due to the fact that the data collected over the different date and interval
#
# 2. Unemployment varable having outliers both the side of the wiskers and having mean of 7.96 and median of 7.86.
#
# 3. outliers might need some treatments.

# %%
charts(df['IsHoliday'] , 1 , (18,7))

# %%
df['IsHoliday'].describe().T
# Out:
# count    421570.000000
# mean          0.070358
# std           0.255750
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: IsHoliday, dtype: float64

# %%
charts(df['Weekly_Sales'] , 0 , (18,7))

# %%
charts(df['Weekly_Sales'] , 2 , (18,7))

# %%
charts(df['Weekly_Sales'] , 3 , (18,7))

# %%
pd.concat([
    pd.DataFrame(df['Weekly_Sales'].describe()) ,
    pd.DataFrame([df['Weekly_Sales'].skew()] , index=['Skew'] , columns = ['Weekly_Sales'])
] , axis = 0).T
# Out:
#                  count          mean           std      min      25%      50%  \
# Weekly_Sales  421570.0  15981.258123  22711.183519 -4988.94  2079.65  7612.03
#
#                      75%        max      Skew
# Weekly_Sales  20205.8525  693099.36  3.262008

# %% [markdown]
# 1. Weekly_Sales variable is very highly skewed (3.26).
#
# 2. Weekly_Sales variable has 15981.25 as mean and 7612.03 as median.
#
# 3. There are outlier present above higher wisker which might need some treatment.

# %%
cor = df.corr()
cor
# Out:
#                  Store      Dept      Size  MarkDown1  MarkDown2  MarkDown3  \
# Store         1.000000  0.024004 -0.182881  -0.059844  -0.033829  -0.020331
# Dept          0.024004  1.000000 -0.002966   0.001494   0.000587   0.001475
# Size         -0.182881 -0.002966  1.000000   0.169788   0.078372   0.033641
# MarkDown1    -0.059844  0.001494  0.169788   1.000000   0.174868  -0.014411
# MarkDown2    -0.033829  0.000587  0.078372   0.174868   1.000000  -0.006080
# MarkDown3    -0.020331  0.001475  0.033641  -0.014411  -0.006080   1.000000
# MarkDown4    -0.042724  0.001937  0.127334   0.838904   0.113250  -0.012020
# MarkDown5    -0.012452  0.002668  0.153011   0.415050   0.131735   0.042471
# CPI          -0.211088 -0.007477 -0.003314   0.010915  -0.003554  -0.005839
# Temperature  -0.050097  0.004437 -0.058313  -0.026415  -0.179672  -0.056026
# Fuel_Price    0.065290  0.003572  0.003361   0.297056   0.029153   0.018615
# ...

# %% [markdown]
# # Analyzing Filling Of NaNs With Median On Markdowns

# %%
df = pd.read_csv('../dataset/filled_med/merged.csv' , index_col=[0])

# %%
df.head()
# Out:
#          Date  Store  Dept Type    Size  MarkDown1  MarkDown2  MarkDown3  \
# 0  2010-05-02      1     1    A  151315    5347.45      192.0       24.6
# 1  2010-05-02      1     2    A  151315    5347.45      192.0       24.6
# 2  2010-05-02      1     3    A  151315    5347.45      192.0       24.6
# 3  2010-05-02      1     4    A  151315    5347.45      192.0       24.6
# 4  2010-05-02      1     5    A  151315    5347.45      192.0       24.6
#
#    MarkDown4  MarkDown5         CPI  Temperature  Fuel_Price  Unemployment  \
# 0    1481.31    3359.45  211.096358        42.31       2.572         8.106
# 1    1481.31    3359.45  211.096358        42.31       2.572         8.106
# 2    1481.31    3359.45  211.096358        42.31       2.572         8.106
# 3    1481.31    3359.45  211.096358        42.31       2.572         8.106
# 4    1481.31    3359.45  211.096358        42.31       2.572         8.106
#
#    IsHoliday  Weekly_Sales
# 0          0      24924.50
# ...

# %%
df.describe()
# Out:
#                Store           Dept           Size      MarkDown1  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317  136727.915739    6026.195471
# std        12.785297      30.492054   60980.583328    5039.770624
# min         1.000000       1.000000   34875.000000       0.270000
# 25%        11.000000      18.000000   93638.000000    5347.450000
# 50%        22.000000      37.000000  140167.000000    5347.450000
# 75%        33.000000      74.000000  202505.000000    5347.450000
# max        45.000000      99.000000  219622.000000   88646.760000
#
#            MarkDown2      MarkDown3      MarkDown4      MarkDown5  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean     1021.307467     484.687953    2090.196076    3815.475623
# std      5060.726828    5527.479863    3669.249108    3625.326240
# min      -265.760000     -29.100000       0.220000     135.160000
# ...

# %%
df.info() # verify updates
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 421570 entries, 0 to 421569
# Data columns (total 16 columns):
# Date            421570 non-null object
# Store           421570 non-null int64
# Dept            421570 non-null int64
# Type            421570 non-null object
# Size            421570 non-null int64
# MarkDown1       421570 non-null float64
# MarkDown2       421570 non-null float64
# MarkDown3       421570 non-null float64
# MarkDown4       421570 non-null float64
# MarkDown5       421570 non-null float64
# CPI             421570 non-null float64
# Temperature     421570 non-null float64
# Fuel_Price      421570 non-null float64
# Unemployment    421570 non-null float64
# IsHoliday       421570 non-null int64
# Weekly_Sales    421570 non-null float64
# dtypes: float64(10), int64(4), object(2)
# memory usage: 54.7+ MB

# %%
charts(df['MarkDown1'] , 2 , (18,7))

# %%
charts(df['MarkDown1'] , 3 , (18,7))

# %%
pd.concat([
    pd.DataFrame(df['MarkDown1'].describe()) ,
    pd.DataFrame([df['MarkDown1'].skew()] , index=['Skew'] , columns = ['MarkDown1'])
] , axis = 0).T
# Out:
#               count         mean          std   min      25%      50%  \
# MarkDown1  421570.0  6026.195471  5039.770624  0.27  5347.45  5347.45
#
#                75%       max      Skew
# MarkDown1  5347.45  88646.76  6.024722

# %% [markdown]
# 1. MarkDown1 variable has multiple peaks in its distribution which is due to the fact that is data has multiple catorigry and each catorigry has different means.
#
# 2. The mean (2590.07) and strange median (0) has significant difference and the data is highly +vely skewed (4.73).
#
# 3. There many outliers present above the higer wisker which requide appropriate treatment.

# %%
charts(df['MarkDown2'] , 2 , (18,7))

# %%
charts(df['MarkDown2'] , 3 , (18,7))

# %%
pd.concat([
    pd.DataFrame(df['MarkDown2'].describe()) ,
    pd.DataFrame([df['MarkDown2'].skew()] , index=['Skew'] , columns = ['MarkDown2'])
] , axis = 0).T
# Out:
#               count         mean          std     min    25%    50%    75%  \
# MarkDown2  421570.0  1021.307467  5060.726828 -265.76  192.0  192.0  192.0
#
#                  max       Skew
# MarkDown2  104519.54  10.715156

# %% [markdown]
# 1. MarkDown2 variable has multiple peaks in its distribution which is due to the fact that is data has multiple catorigry and each catorigry has different means.
#
# 2. The mean (879.97) and strange median (0) has significant difference and the data is highly +vely skewed (10.6).
#
# 3. There many outliers present above the higer wisker which requide appropriate treatment.

# %%
charts(df['MarkDown3'] , 2 , (18,7))

# %%
charts(df['MarkDown3'] , 3 , (18,7))

# %%
pd.concat([
    pd.DataFrame(df['MarkDown3'].describe()) ,
    pd.DataFrame([df['MarkDown3'].skew()] , index=['Skew'] , columns = ['MarkDown3'])
] , axis = 0).T
# Out:
#               count        mean          std   min   25%   50%   75%  \
# MarkDown3  421570.0  484.687953  5527.479863 -29.1  24.6  24.6  24.6
#
#                  max       Skew
# MarkDown3  141630.61  14.924682

# %% [markdown]
# 1. MarkDown3 variable has multiple peaks in its distribution which is due to the fact that is data has multiple catorigry and each catorigry has different means.
#
# 2. The mean (468.08) and strange median (0) has significant difference and the data is highly +vely skewed (14.9).
#
# 3. There many outliers present above the higer wisker which requide appropriate treatment.

# %%
charts(df['MarkDown4'] , 2 , (18,7))

# %%
charts(df['MarkDown4'] , 3 , (18,7))

# %%
pd.concat([
    pd.DataFrame(df['MarkDown4'].describe()) ,
    pd.DataFrame([df['MarkDown4'].skew()] , index=['Skew'] , columns = ['MarkDown4'])
] , axis = 0).T
# Out:
#               count         mean          std   min      25%      50%  \
# MarkDown4  421570.0  2090.196076  3669.249108  0.22  1481.31  1481.31
#
#                75%       max      Skew
# MarkDown4  1481.31  67474.85  8.833014

# %% [markdown]
# 1. MarkDown4 variable has multiple peaks in its distribution which is due to the fact that is data has multiple catorigry and each catorigry has different means.
#
# 2. The mean (1083.13) and strange median (0) has significant difference and the data is highly +vely skewed (8.07).
#
# 3. There many outliers present above the higer wisker which requide appropriate treatment.

# %%
charts(df['MarkDown5'] , 2 , (18,7))

# %%
charts(df['MarkDown5'] , 3 , (18,7))

# %%
pd.concat([
    pd.DataFrame(df['MarkDown5'].describe()) ,
    pd.DataFrame([df['MarkDown5'].skew()] , index=['Skew'] , columns = ['MarkDown5'])
] , axis = 0).T
# Out:
#               count         mean         std     min      25%      50%  \
# MarkDown5  421570.0  3815.475623  3625.32624  135.16  3359.45  3359.45
#
#                75%        max       Skew
# MarkDown5  3359.45  108519.28  13.715314

# %%
cor = df.corr()
cor
# Out:
#                  Store      Dept      Size  MarkDown1  MarkDown2  MarkDown3  \
# Store         1.000000  0.024004 -0.182881  -0.070700  -0.032997  -0.020293
# Dept          0.024004  1.000000 -0.002966  -0.000587   0.000564   0.001468
# Size         -0.182881 -0.002966  1.000000   0.203202   0.077080   0.033534
# MarkDown1    -0.070700 -0.000587  0.203202   1.000000   0.088357  -0.075525
# MarkDown2    -0.032997  0.000564  0.077080   0.088357   1.000000  -0.008702
# MarkDown3    -0.020293  0.001468  0.033534  -0.075525  -0.008702   1.000000
# MarkDown4    -0.027762  0.002169  0.112056   0.816148   0.069051  -0.035481
# MarkDown5    -0.015393  0.000896  0.179588   0.186165   0.047080  -0.001381
# CPI          -0.211088 -0.007477 -0.003314  -0.021389  -0.004514  -0.005974
# Temperature  -0.050097  0.004437 -0.058313  -0.025144  -0.179142  -0.055968
# Fuel_Price    0.065290  0.003572  0.003361   0.110255   0.023717   0.017681
# ...

# %% [markdown]
# 1. MarkDown5 variable has multiple peaks in its distribution which is due to the fact that is data has multiple catorigry and each catorigry has different means.
#
# 2. The mean (1662.77) and strange median (0) has significant difference and the data is highly +vely skewed (9.96).
#
# 3. There many outliers present above the higer wisker which requide appropriate treatment.

# %% [markdown]
# # Bivarite Analysis

# %% [markdown]
# 1. Using Filled_Zero Dataset

# %% [markdown]
# 2. Using Filled_Median Dataset
